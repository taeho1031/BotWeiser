# %% [markdown]
# ## Sementic Search Test

# %%
import weaviate
import json

client = weaviate.Client(
    url= "https://fortainfinity-botweiser-grztbyru.weaviate.network/",  # Replace with your endpoint
    auth_client_secret=weaviate.AuthApiKey(api_key= "PBdt4BX3BE2bHVeBlN9xMs03E4GFrGcYtM2A"),  # Replace w/ your Weaviate instance API key
    additional_headers={
        "X-OpenAI-Api-Key": "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"  # Replace with your inference API key
    }
)
# Out:
# c:\Users\Taeho Kim\AppData\Local\Programs\Python\Python312\Lib\site-packages\weaviate\warnings.py:121: DeprecationWarning: Dep005: You are using weaviate-client version 3.26.2. The latest version is 4.4.4.
#             Please consider upgrading to the latest version. See https://weaviate.io/developers/weaviate/client-libraries/python for details.
#   warnings.warn(

# %% [markdown]
# ## Weaviate Search Test Implementation
#
#
# The object in Weaviate Clusters have attributes:\
# "bot_id", "name", "description", "timestamp", "chainIds"

# %% [markdown]
# ### Direct Questions
#
# Questions that describe certain bots that already exists in the database.

# %% [markdown]
# 1. Give me a bot that identifies protocol attacks in real-time\
# \
# Expected: Attack Detector Feed (beta alt)
# \
# Actual Result (Certainty):\
# A. Attack Detector Feed (beta alt) - 0.9210962057113647\
# B. anomalous-token-transfers-detection-ml - 0.919776052236557\
# C. Forta MEV bot detector - 0.9197012782096863\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned first on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Identifies", "Protocol attacks", "Real-time"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9210962057113647,
#             "generate": {
#               "error": null,
# ...

# %% [markdown]
# 2. I want a bot that is designed to detect asset drainage in smart contracts.
# \
# \
# Expected: Asset Drained
# \
# Actual Result (Certainty):\
# A. Asset Drained - 0.9329408407211304\
# B. harry-bot-threatintel - 0.9271435737609863\
# C. ironbank-implementation-changed - 0.9271336197853088\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned first on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Detect", "Asset drainage", "Smart contracts"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9329408407211304,
#             "generate": {
#               "error": null,
#               "singleResult": "- The blockchain bot monitors ERC20 and native token transfers in smart contracts to detect asset drainage.\n- It triggers alerts when 99% or more of a contract's assets are drained within a single block.\n- The bot operates across various blockchain networks and issues high-severity alerts for significant asset reductions.\n- It provides detailed metadata, including contract addresses, affected assets, transaction details, and anomaly scores, to identify victims and suspected attackers."
#             }
#           },
#           "name": "Asset Drained"
#         },
#         {
#           "_additional": {
#             "certainty": 0.9271435737609863,
#             "generate": {
#               "error": null,
# ...

# %% [markdown]
# 3. Give a bot that detects and alerts on different types of evasion tactics used by smart contracts on the Ethereum blockchain
# \
# \
# Expected: forta-bot-evasion
# \
# \
# Actual Result (Certainty):\
# A. harry-bot-threatintel - 0.9317328631877899\
# B. forta-bot-evasion - 0.9288537204265594\
# C. BlockSec Phishing Alert - 0.9279823005199432\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned second on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name", "chainIds"])
    .with_where({
        "path": ["chainIds"],
        "operator": "Equal",
        "valueNumber": 1
    })
    .with_near_text({"concepts":["evasion tactics", "smart contracts", "alerts", "Ethereum"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.931736409664154,
#             "generate": {
#               "error": null,
#               "singleResult": "- Monitoring Ethereum blockchain for signs of malicious activities\n- Analyzing smart contract activities, particularly Tether transfers\n- Detecting indicators of scams such as new smart contracts and suspicious function signatures\n- Managing alert frequency with severity levels and utilizing real-time Tether price data for assessment"
#             }
#           },
#           "chainIds": [
#             1,
#             137
#           ],
#           "name": "harry-bot-threatintel"
#         },
#         {
#           "_additional": {
#             "certainty": 0.9288590252399445,
#             "generate": {
#               "error": null,
# ...

# %% [markdown]
# 4. Recommend a bot that is primarily designed to monitor and analyze transactions executed from bridge receivers' timelocks.
# \
# \
# Expected: Compound v3 Timelock Transaction Executions Monitor
# \
# Actual Result (Certainty):\
# A. timelock-controller-monitor - 0.9127992987632751\
# B. Compound v3 Timelock Transaction Executions Monitor - 0.9088267982006073\
# C. Large Balance Decrease - Avalanche Bridge - 0.907536655664444\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned second on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["bridge receivers", "timeclock", "transactions"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9127992987632751,
#             "generate": {
#               "error": null,
#               "singleResult": "- The web3 bot is programmed to scan transaction logs on the Ethereum blockchain to identify role changes within a Timelock Controller contract.\n- It is designed to differentiate between role grants, revokes, and renouncements, and generate reports based on these actions.\n- The bot categorizes different roles within the contract and evaluates the impact of role changes based on predefined criteria.\n- By monitoring and enforcing access control policies, the bot helps maintain the security and integrity of decentralized applications running on the blockchain."
#             }
#           },
#           "name": "timelock-controller-monitor"
#         },
#         {
#           "_additional": {
#             "certainty": 0.9088267982006073,
# ...

# %% [markdown]
# 5. Which bot monitors and analyzes NFT transactions across multiple blockchain marketplaces, such as OpenSea, LooksRare, and Blur, to detect suspicious activities that may be indicative of scams or phishing attempts
# \
# \
# Expected: Scammer-NFT-trader
# \
# \
# Actual Result (Certainty):\
# A. scammer-nft-trader - 0.924324095249176\
# B. NFT Sleep Minting Detection - 0.9228537082672119\
# C. phishing-scam-detection-ml-bot - 0.9209881126880646\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned first on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["NFT", "transactions", "OpenSea", "LooksRare", "Blur", "scams", "phishing"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.924324095249176,
#             "generate": {
#               "error": null,
#               "singleResult": "- The web3 bot monitors and analyzes NFT transactions across various blockchain marketplaces to detect suspicious activities indicative of scams or phishing attempts.\n- It stores transaction records locally in a MySQL database to facilitate anomaly detection, such as sales significantly deviating from floor prices or unusually rapid sales.\n- The bot issues alerts for various detected activities, including abnormal price differences, potential phishing sales below a specified threshold, and alerts for stolen NFTs possibly involved in phishing attacks.\n- Supported blockchain networks include Ethereum, BSC, Polygon, Optimism, Fantom, Arbitrum, Avalanche, and more, enhancing transparency and security in the NFT marketplace."
#             }
#           },
# ...

# %% [markdown]
# 6. Send me a bot that is designed to detect spam tokens within blockchain networks using advanced algorithms that analyze multiple indicators.
# \
# \
# Expected: Token Spam Detector / Sandbox
# \
# \
# Actual Result (Certainty):\
# A. Token Spam Detector / Sandbox - 0.9312174022197723\
# B. Token Spam Detector - 0.9307655096054077\
# C. phishing-scam-detection-ml-bot - 0.9280945956707001\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned first on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Detect", "Spam tokens", "Blockchain networks", "Advanced algorithms", "Multiple indicators"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9312174022197723,
#             "generate": {
#               "error": null,
# ...

# %% [markdown]
# 7. Can I have a bot designed to monitor the Ethereum blockchain for indicators of malicious activity related to draining funds from users, such as through scam transactions.
# \
# \
# Expected: harry-bot-threatintel
# \
# \
# Actual Result (Certainty):\
# A. harry-bot-threatintel - 0.9345957636833191\
# B. Asset Drained - 0.9277911186218262\
# C. BlockSec Phishing Alert - 0.9277039170265198\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned first on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Monitor", "Ethereum blockchain", "Indicators", "Malicious activity", "Draining funds", "Scam transactions"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9345957636833191,
#             "generate": {
#               "error": null,
#               "singleResult": "- Monitoring Ethereum blockchain for malicious activities, specifically unauthorized fund draining and scam transactions\n- Analyzing smart contract activities, focusing on Tether (USDT) transfers linked to potential malicious behavior\n- Utilizing code structure with modules for detecting scam indicators, such as new smart contract creation and suspicious Tether transfers\n- Employing severity levels for alert management, real-time Tether price data for financial impact assessment, and a list of ignored addresses for filtering benign entities"
#             }
#           },
#           "name": "harry-bot-threatintel"
#         },
#         {
#           "_additional": {
#             "certainty": 0.9277911186218262,
#             "generate": {
# ...

# %% [markdown]
# 8. Give me a bot that monitors notification EOAs to track and alert the scam activities.
# \
# \
# Expected: Scam Notifier Bot
# \
# \
# Actual Result (Certainty):\
# A. harry-bot-threatintel - 0.9177755415439606\
# B. phishing-scam-detection-ml-bot - 0.9170756340026855\
# C. NFT Sleep Minting Detection - 0.9166624546051025\
# D. scam-notifier-bot - 0.9143936038017273 (13th on the list)\
# \
# Result: Using sementic search, all the returned bots are relevant, but the expected bot is returned 13th on the list. ❌

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Monitors", "Notification", "EOAs", "Track", "Alert", "Scam activities"]})
    .with_limit(13)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9177755415439606,
#             "generate": {
#               "error": null,
#               "singleResult": "- Monitoring Ethereum blockchain for malicious activities, particularly unauthorized fund draining\n- Analyzing smart contract activities, focusing on Tether transfers linked to potential scams\n- Using code structure with modules to detect indicators of scams, such as new smart contract creation and suspicious Tether transfers\n- Employing severity levels for alert management, real-time Tether price data for financial impact assessment, and maintaining a list of addresses to ignore for filtering benign entities"
#             }
#           },
#           "name": "harry-bot-threatintel"
#         },
#         {
#           "_additional": {
#             "certainty": 0.9170756340026855,
#             "generate": {
#               "error": null,
# ...

# %% [markdown]
# 9. I want a security bot that consists of multiple parts that involve detecting attacks on Ethereum-like smart contract protocols in real-time and handling false positives within the Web3 ecosystem.
# \
# \
# Expected: Attack Detector Feed (beta)
# \
# \
# Actual Result (Certainty):\
# A. BlockSec Phishing Alert - 0.93539097905159\
# B. Attack Detector Feed (beta alt) - 0.9350938498973846\
# C. harry-bot-threatintel - 0.9335703253746033\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned second on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Security bot", "Detecting attacks", "Smart contract protocols", "Real-time", "Handling", "False positives", "Web3 ecosystem"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9353919625282288,
#             "generate": {
#               "error": null,
#               "singleResult": "- The Web3 bot is designed to monitor and alert against various forms of phishing and scams on the Ethereum blockchain.\n- It utilizes JavaScript modules to interact with the blockchain, handle smart contract transactions, categorize alerts, and encrypt sensitive data.\n- The bot uses APIs like Moralis and AlchemySDK to gather transaction details and predefined patterns to analyze transaction data for fraudulent activities.\n- Key components include defining constants and ABIs, processing phishing transactions, managing alerts, handling marketplace transactions, recognizing phishing attacks, and communicating with external APIs like Etherscan."
#             }
#           },
#           "name": "BlockSec Phishing Alert"
#         },
#         {
# ...

# %% [markdown]
# 10. Show me a bot that is a security agent designed to monitor and report wallet balances for a series of fleet_keys and pink_panther accounts on different networks, such as Ethereum (ETH), Binance Smart Chain (BSC), and Polygon (MATIC).
# \
# \
# Expected: minimum-balance
# \
# \
# Actual Result (Certainty):\
# A. minimum-balance - 0.9300459623336792\
# B. harry-bot-threatintel - 0.9263944029808044\
# C. shell-v2-forta-agent - 0.9255450069904327\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned first on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Security agent", "Wallet balances", "Fleet_keys", "Pink_panther accounts", "Networks", "Ethereum (ETH)", "Binance Smart Chain (BSC)", "Polygon (MATIC)"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9300459623336792,
#             "generate": {
#               "error": null,
#               "singleResult": "- The web3 bot is designed to monitor and report wallet balances for specific accounts across multiple blockchain networks, including Ethereum, Binance Smart Chain, and Polygon.\n- It conducts periodic balance checks to detect when balances fall below predefined thresholds, triggering alerts to notify users of potential issues.\n- Users have the ability to customize thresholds and monitored wallets, using variables like `MIN_BALANCE` for each network to tailor the bot's monitoring capabilities.\n- The bot utilizes JavaScript, asynchronous functions, the Forta Agent SDK, Ethers.js, and BigNumber.js for numerical operations, with execution managed through npm commands and testing with `npm test`."
#             }
#           },
# ...

# %% [markdown]
# 11. Provide a bot that identifies victims of end-user attacks and calculates their losses.
# \
# \
# Expected: Victim & Loss Identifier
# \
# \
# Actual Result (Certainty):\
# A. Victim & Loss Identifier - 0.9202452301979065\
# B. Victim Identifier - 0.9172751903533936\
# C. harry-bot-threatintel - 0.9147704541683197\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned first on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Identifies", "Victims", "End-user attacks", "Calculates", "Losses"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9202452301979065,
#             "generate": {
#               "error": null,
#               "singleResult": "- The Victim & Loss Identifier Bot receives alerts from the Scam Detector Feed bot regarding potential scams, particularly fraudulent NFT orders.\n- It identifies and tracks scammer addresses and assesses the nature of threats they pose by investigating historical data spanning 90 days.\n- The bot calculates the USD value of digital assets transferred to scammers and continues to monitor scammer activity for 30 days following the last known incident.\n- It communicates findings through info alerts, detailing victim addresses, scammer details, lost amounts, transaction hashes, and ERC-721 token information, while also issuing false positive alerts to mark previously identified scammers as benign."
#             }
#           },
# ...

# %% [markdown]
# 12. Which bot detects large profits.
# \
# \
# Expected: Large-Profit-Bot
# \
# \
# Actual Result (Certainty):\
# A. large-profit-bot - 0.9230323433876038\
# B. ironbank-implementation-changed - 0.9180367588996887\
# C. iron-bank-high-number-of-markets - 0.9166665077209473\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned first on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Detects", "Large profits"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9230323433876038,
#             "generate": {
#               "error": null,
#               "singleResult": "- The Large Profit Bot is designed to track blockchain transactions across multiple chains to identify those yielding substantial profits for the initiator.\n- It defines significant profits as exceeding $10,000 or 5% of a token's total supply and issues \"LARGE-PROFIT\" alerts with medium severity upon detecting such transactions.\n- The bot leverages Moralis and block explorer APIs for data acquisition and advises users to integrate their API keys for optimal performance.\n- It supports multiple chains including Ethereum, Optimism, BNB Smart Chain, Polygon, Fantom, Arbitrum, and Avalanche, providing metadata such as transaction initiator, called contract, anomaly scores, and profit amounts in its alerts."
#             }
#           },
# ...

# %% [markdown]
# 13. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Detects", "MEV bots", "Strategies", "Extract value", "Protocol", "Adding", "Removing", "Reordering", "Transactions", "Block"]})
    .with_limit(3)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9186564981937408,
#             "generate": {
#               "error": null,
#               "singleResult": "- The detection bot uses machine learning models to analyze transaction features and determine if they are normal or suspicious.\n- It assesses attributes such as token types, transfer counts, and account activity periods to gauge the likelihood of an anomaly.\n- The bot aims to monitor token transactions on the Ethereum blockchain and identify potential security threats or irregularities.\n- By emitting findings based on its analysis, the bot helps to enhance security and prevent fraudulent activities in the network."
#             }
#           },
#           "name": "anomalous-token-transfers-detection-ml"
#         },
#         {
#           "_additional": {
#             "certainty": 0.9182378053665161,
#             "generate": {
# ...

# %% [markdown]
# 14. I want a bot that provides real-time alerts on potential Sybil Attacks
# \
# \
# Expected: Sybil Defender
# \
# \
# Actual Result (Certainty):\
# A. sybil-attack-detection-bot - 0.9257964789867401\
# B. Attack Detector Feed (beta alt) - 0.9244359731674194\
# C. phishing-scam-detection-ml-bot - 0.9220010340213776\
# \
# Result: Using sementic search, all the returned bots are relevant, but the expected bot wasn't returned within the first thirty on the list. ❌

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Real-time alerts", "Potential", "Sybil Attacks"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9257964789867401,
#             "generate": {
#               "error": null,
# ...

# %% [markdown]
# 15. Which bot uses machine learning-based system for real-time detection against malicious contracts based on bytecode
# \
# \
# Expected: Neurablack-ML-Bytecode-Detector
# \
# \
# Actual Result (Certainty):\
# A. OpBERT Malicious Contract Detector - 0.9345903992652893\
# B. ironbank-implementation-changed - 0.9327077865600586\
# C. phishing-scam-detection-ml-bot - 0.9312810003757477\
# \
# Result: Using sementic search, all the returned bots are relevant, but the expected bot wasn't returned within the first thirty on the list. ❌

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "_additional": {
#             "certainty": 0.9345903992652893,
#             "generate": {
#               "error": null,
#               "singleResult": "- The Malicious Contract Detector bot utilizes machine learning, specifically a BERT transformer model, to distinguish potentially harmful smart contracts on the blockchain.\n- The project explores various algorithms and features to enhance the model's capability in recognizing dangerous contracts in two phases.\n- Components like `findings.py`, `logger.py`, and `agent.py` are included in the provided source code to handle the analysis and orchestration of blockchain transactions.\n- The bot employs a pretrained `DistilBertForSequenceClassification` model with custom weights and a `DistilBertTokenizerFast` tokenizer for efficient processing of incoming contracts in real-time with accuracy."
#             }
#           },
# ...

# %% [markdown]
# ### Paraphrased Questions
#
# Questions that we currently do not know if they exist in database.

# %% [markdown]
# 1. What type of Web3 bot would be recommended for monitoring and alerting on decreases in the virtual prices of AA (senior) and BB (junior) tranches within Idle Finance's Perpetual Yield Tranches in the DeFi ecosystem on the Ethereum blockchain
# \
# \
# Expected: Idle PYTs tranche virtualPrice decrease
# \
# \
# Actual Result (Certainty):\
# A. Idle PYTs tranche virtualPrice decrease - 0.9351778030395508\
# B. iron-bank-drastic-liquidity-change-for-time-period - 0.9294796586036682\
# C. Unhealthy-Borrow-Reporter - 0.9275070428848267\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Web3 bot", "Monitoring", "Alerting", "Virtual prices", "AA tranches", "BB tranches", "DeFi ecosystem"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": null
#     }
#   },
#   "errors": [
#     {
#       "locations": [
#         {
#           "column": 6,
#           "line": 1
#         }
#       ],
#       "message": "explorer: get class: vectorize params: vectorize params: vectorize params: vectorize keywords: remote client vectorize: connection to: OpenAI API failed with status: 429 error: You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.",
#       "path": [
#         "Get",
#         "FortaBot"
#       ]
#     }
#   ]
# }

# %% [markdown]
# 2. Recommend a bot that identifies fraudulent tokens engaged in rake scams, which impose an extra swap fee on the Uniswap decentralized exchange and divert it to an externally owned account.
# \
# \
# Expected: rake-scam-token-detection-bot
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
# Out:
# {
#   "data": {
#     "Get": {
#       "FortaBot": [
#         {
#           "name": "rake-scam-token-detection-bot"
#         },
#         {
#           "name": "harry-bot-threatintel"
#         },
#         {
#           "name": "Large Balance Decrease - Avalanche Bridge"
#         }
#       ]
#     }
#   }
# }

# %% [markdown]
# 3. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 4. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 5. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 6. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 7. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 8. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 9. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 10. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 11. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 12. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 13. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 14. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)

# %% [markdown]
# 15. Recommend me a bot that detects MEV bots that uses different strategies to extract value from a protocol by adding, removing or reordering transactions in a block
# \
# \
# Expected: Forta MEV bot detector
# \
# \
# Actual Result (Certainty):\
# A. anomalous-token-transfers-detection-ml - 0.9186564981937408\
# B. Large Balance Decrease - Avalanche Bridge - 0.9182378053665161\
# C. Forta MEV bot detector - 0.9177805185317993\
# \
# Result: Using sementic search, all the returned bots are relevant, and the expected bot is returned third on the list. ✅

# %%
response = (
    client.query
    .get("FortaBot", ["name"])
    .with_near_text({"concepts":["Bot", "Machine learning-based system", "Real-time detection", "Malicious contracts", "Bytecode"]})
    .with_limit(30)
    .with_generate(single_prompt="Explain how {description} answers 'concepts' in 4 bullet points.")
    .with_additional(["certainty"])
    .do()
)

response_json = json.dumps(response, indent=2) 
print(response_json)
